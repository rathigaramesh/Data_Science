# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#Quan=["ssc_p","hsc_p","etest_p","degree_p","mba_p","salary"]
#Qual=["gender","ssc_b","hsc_b","degree_t"]

# %%
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dataset["ssc_p"].dtypes
# Out:
# dtype('float64')

# %%
for columnName in dataset.columns:
    print(columnName)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
if(dataset["ssc_p"].dtype=='O'):
    print("qual")
else:
    print("quan")
# Out:
# quan

# %%
quan=[]
qual=[]
for columnName in dataset.columns:
    #print(columnName)
    if(dataset[columnName].dtype=='O'):
        #print("qual")
        qual.append(columnName)
    else:
        #print("quan")
        quan.append(columnName)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quanQual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
quan,qual=quanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Central tendency

# %%
#Cell -> celltype->markdown -> #Central Tendency

# %% [markdown]
# #MEAN, MEDIAN, MODE

# %%
dataset["ssc_p"].mean()
# Out:
# 67.30339534883721

# %%
dataset["ssc_p"].median()
# Out:
# 67.0

# %%
dataset["ssc_p"].mode()[0]
# Out:
# 62.0

# %%
dataset["ssc_p"].mode()
# Out:
# 0    62.0
# dtype: float64

# %%
dataset.describe() #quantitative data
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
# | Statistic | Meaning                     |
# | --------- | --------------------------- |
# | `count`   | Number of non-null values   |
# | `mean`    | Average value               |
# | `std`     | Standard deviation (spread) |
# | `min`     | Minimum value               |
# | `25%`     | 25th percentile (Q1)        |
# | `50%`     | 50th percentile (Median)    |
# | `75%`     | 75th percentile (Q3)        |
# | `max`     | Maximum value               |

# %%
descriptive=pd.DataFrame() #A DataFrame is a 2D table-like data structure in Pandas

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"])

# %%
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: [Mean, Median, Mode]

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive["hsc_p"]["Median"]=0

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN     0      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    NaN        NaN        NaN        NaN        NaN        NaN
# Mode      NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median            NaN
# Mode              NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode      NaN        NaN        NaN        NaN        NaN        NaN
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode              NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %% [markdown]
# # Percertile

# %%
import numpy as np
# NumPy is used for fast and efficient numerical operations, especially on large datasets.
# It provides powerful array/matrix handling with built-in math functions.

# %%
np.percentile(dataset["ssc_p"],100)
# Out:
# 89.4

# %%
np.percentile(dataset["ssc_p"],17)
# Out:
# 56.1064

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=np.percentile(dataset[columnName],25)

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%     NaN        NaN        NaN        NaN        NaN        NaN
# Q3:75%     NaN        NaN        NaN        NaN        NaN        NaN
# 99%        NaN        NaN        NaN        NaN        NaN        NaN
# Q4:100%    NaN        NaN        NaN        NaN        NaN        NaN
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%             NaN
# Q2:50%             NaN
# Q3:75%             NaN
# 99%                NaN
# Q4:100%            NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# 99%                NaN
# Q4:100%       940000.0

# %% [markdown]
# # Interquartile Range IQR (Lesser and Greater)

# %%
# | Statistic | Meaning                             |
# | --------- | ----------------------------------- |
# | Mean      | Average                             |
# | Median    | 50th percentile (Q2)                |
# | Mode      | Most frequent value                 |
# | Q1:25%    | 25th percentile (lower quartile)    |
# | Q2:50%    | 50th percentile (median)            |
# | Q3:75%    | 75th percentile (upper quartile)    |
# | 99%       | 99th percentile                     |
# | Q4:100%   | Maximum                             |
# | IQR       | Interquartile Range (Q3 - Q1)       |
# | 1.5rule   | 1.5 × IQR (used for outlier bounds) |
# | Lesser    | Q1 - 1.5×IQR (lower outlier limit)  |
# | Greater   | Q3 + 1.5×IQR (upper outlier limit)  |
# | Min       | Minimum value                       |
# | Max       | Maximum value                       |

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Min"]=dataset[columnName].min()
    descriptive[columnName]["Max"]=dataset[columnName].max()

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
# Lesser outline -> Lesser=-106, Min =1    (-106<1), same for 37.95<40.89, 42.75<37, 44.5<50,24.75<50,45.48<51.21
  #But the above 42.75<37 condition failed outlier present so need to replace
    
    
# Greater outline -> Greater =322, Max =215 (322>215) same for 98.35>89.4, 91.15>97.7, 88.5>91, 118.75>98,78.72>77.89

# %%
descriptive["hsc_p"]["Lesser"]<descriptive["hsc_p"]["Min"]
#42.75<37
# Out:
# False

# %%
descriptive["hsc_p"]["Min"] <descriptive["hsc_p"]["Lesser"]
# Out:
# True

# %%
lesser=[]
greater=[]

for columnName in quan:
    if(descriptive[columnName]["Min"]<descriptive[columnName]["Lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["Max"]>descriptive[columnName]["Greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %% [markdown]
# # Replacing Outliners

# %%
for columnName in lesser:
    #hsc_p [hsc_p<Lesser]=Lesser
    dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]
for column in greater:
     #'hsc_p', 'degree_p', 'salary' ['hsc_p', 'degree_p', 'salary'>Greater]=Greater
    dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]]=descriptive[columnName]["Greater"]
# Out:
# C:\Users\User\anaconda3\envs\AI_MLProject\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\anaconda3\envs\AI_MLProject\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#for check again run the dataset
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Mean"]=dataset[columnName].mean()
    descriptive[columnName]["Median"]=dataset[columnName].median()
    descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["Min"]=dataset[columnName].min()
    descriptive[columnName]["Max"]=dataset[columnName].max()

# %% [markdown]
# # Before Replace Outliners Values
#
# | **Stat**    | **Col1** | **Col2** | **Col3** | **Col4** | **Col5** | **Col6** | **Col7** |
# | ----------- | -------- | -------- | -------- | -------- | -------- | -------- | -------- |
# | **Lesser**  | -106     | 37.95    | 42.75    | 44.5     | 24.75    | 45.48    | 150000   |
# | **Min**     | 1        | 40.89    | 37       | 50       | 50       | 51.21    | 200000   |
# | **Greater** | 322      | 98.35    | 91.15    | 88.5     | 118.75   | 78.72    | 390000   |
# | **Max**     | 215      | 89.4     | 97.7     | 91       | 98       | 77.89    | 940000   |

# %% [markdown]
# # After Replace Outliners Values
# | Stat        | Col1   | Col2  | Col3  | Col4 | Col5   | Col6  | Col7     |
# | ----------- | ------ | ----- | ----- | ---- | ------ | ----- | -------- |
# | **Lesser**  | -106.0 | 37.95 | 42.75 | 44.5 | 24.75  | 45.48 | 150000.0 |
# | **Min**     | 1      | 40.89 | 42.75 | 50.0 | 50.0   | 51.21 | 200000.0 |
# | **Greater** | 322.0  | 98.35 | 91.15 | 88.5 | 118.75 | 78.72 | 390000.0 |
# | **Max**     | 215    | 89.4  | 91.15 | 88.5 | 98.0   | 77.89 | 390000.0 |

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0     91.129      83.86       97.0    76.1142
# Q4:100%   215.0       89.4      91.15       91.0       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %% [markdown]
# # Frequency

# %%
dataset["ssc_p"].value_counts()
#Frequency repeated time EX : 62 ->11 times repeated
# Out:
# 62.00    11
# 63.00    10
# 67.00     9
# 52.00     9
# 73.00     9
#          ..
# 69.70     1
# 80.92     1
# 83.00     1
# 86.50     1
# 80.60     1
# Name: ssc_p, Length: 103, dtype: int64

# %%
freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative Frequency","Cusum"])

# %%
freqTable
# Out:
# Empty DataFrame
# Columns: [Unique_Values, Frequency, Relative Frequency, Cusum]
# Index: []

# %%
freqTable["Unique_Values"]=dataset["ssc_p"].value_counts().index
freqTable["Frequency"]=dataset["ssc_p"].value_counts().values

# %%
freqTable
# Out:
#      Unique_Values  Frequency Relative Frequency Cusum
# 0            62.00         11                NaN   NaN
# 1            63.00         10                NaN   NaN
# 2            67.00          9                NaN   NaN
# 3            52.00          9                NaN   NaN
# 4            73.00          9                NaN   NaN
# ..             ...        ...                ...   ...
# 98           69.70          1                NaN   NaN
# 99           80.92          1                NaN   NaN
# 100          83.00          1                NaN   NaN
# 101          86.50          1                NaN   NaN
# 102          80.60          1                NaN   NaN
#
# [103 rows x 4 columns]

# %%
freqTable["Unique_Values"]=dataset["ssc_p"].value_counts().index
freqTable["Frequency"]=dataset["ssc_p"].value_counts().values
freqTable["Relative Frequency"]=(freqTable["Frequency"]/103) #103 column
freqTable["Cusum"]=freqTable["Relative Frequency"].cumsum()

# %%
freqTable
# Out:
#      Unique_Values  Frequency  Relative Frequency     Cusum
# 0            62.00         11            0.106796  0.106796
# 1            63.00         10            0.097087  0.203883
# 2            67.00          9            0.087379  0.291262
# 3            52.00          9            0.087379  0.378641
# 4            73.00          9            0.087379  0.466019
# ..             ...        ...                 ...       ...
# 98           69.70          1            0.009709  2.048544
# 99           80.92          1            0.009709  2.058252
# 100          83.00          1            0.009709  2.067961
# 101          86.50          1            0.009709  2.077670
# 102          80.60          1            0.009709  2.087379
#
# [103 rows x 4 columns]

# %%
def freqTable(columnName,dataset):
    freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative Frequency","Cusum"])
    freqTable["Unique_Values"]=dataset[columnName].value_counts().index
    freqTable["Frequency"]=dataset[columnName].value_counts().values
    freqTable["Relative Frequency"]=(freqTable["Frequency"]/103)
    freqTable["Cusum"]=freqTable["Relative Frequency"].cumsum()
    return freqTable

# %%
freqTable
# Out:
# <function __main__.freqTable(columnName, dataset)>

# %%
freqTable("ssc_p",dataset)
# Out:
#      Unique_Values  Frequency  Relative Frequency     Cusum
# 0            62.00         11            0.106796  0.106796
# 1            63.00         10            0.097087  0.203883
# 2            67.00          9            0.087379  0.291262
# 3            52.00          9            0.087379  0.378641
# 4            73.00          9            0.087379  0.466019
# ..             ...        ...                 ...       ...
# 98           69.70          1            0.009709  2.048544
# 99           80.92          1            0.009709  2.058252
# 100          83.00          1            0.009709  2.067961
# 101          86.50          1            0.009709  2.077670
# 102          80.60          1            0.009709  2.087379
#
# [103 rows x 4 columns]

# %%
freqTable("hsc_p",dataset)
# Out:
#     Unique_Values  Frequency  Relative Frequency     Cusum
# 0           63.00         14            0.135922  0.135922
# 1           62.00         12            0.116505  0.252427
# 2           60.00          9            0.087379  0.339806
# 3           67.00          9            0.087379  0.427184
# 4           70.00          8            0.077670  0.504854
# ..            ...        ...                 ...       ...
# 86          70.29          1            0.009709  2.048544
# 87          83.83          1            0.009709  2.058252
# 88          70.40          1            0.009709  2.067961
# 89          90.90          1            0.009709  2.077670
# 90          61.33          1            0.009709  2.087379
#
# [91 rows x 4 columns]

# %%
# I save as this into fucntion for future reference

# %%
def Univariate_freq(dataset,quan):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
    for columnName in quan:
        descriptive[columnName]["Mean"]=dataset[columnName].mean()
        descriptive[columnName]["Median"]=dataset[columnName].median()
        descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
        descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Min"]=dataset[columnName].min()
        descriptive[columnName]["Max"]=dataset[columnName].max()
    return descriptive

# %%
Univariate_freq(dataset,quan)
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0     91.129      83.86       97.0    76.1142
# Q4:100%   215.0       89.4      91.15       91.0       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %% [markdown]
# # Histogram, Skewness, Kurtosis

# %%
dataset["hsc_p"].skew()
# Out:
# 0.16261050623024148

# %%
dataset["hsc_p"].kurtosis()
# Out:
# 0.08690077018906717

# %%
def Univariate_histSkewKuto(dataset,quan):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%",
                               "Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater",
                                    "Min","Max","kurtosis","skew"],columns=quan)
    for columnName in quan:
        descriptive[columnName]["Mean"]=dataset[columnName].mean()
        descriptive[columnName]["Median"]=dataset[columnName].median()
        descriptive[columnName]["Mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
        descriptive[columnName]["Lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive[columnName]["Min"]=dataset[columnName].min()
        descriptive[columnName]["Max"]=dataset[columnName].max()
        descriptive[columnName]["kurtosis"]=dataset[columnName].kurtosis()
        descriptive[columnName]["skew"]=dataset[columnName].skew()
    return descriptive

# %%
Univariate_histSkewKuto(dataset,quan)
# Out:
#            sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean       108.0  67.303395  66.334744  66.370186  72.100558  62.278186
# Median     108.0       67.0       65.0       66.0       71.0       62.0
# Mode           1       62.0       63.0       65.0       60.0       56.7
# Q1:25%      54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%     108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%     161.5       75.7       73.0       72.0       83.5     66.255
# 99%       212.86       87.0     91.129      83.86       97.0    76.1142
# Q4:100%    215.0       89.4      91.15       91.0       98.0      77.89
# IQR        107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule    160.5      22.65      18.15       16.5      35.25     12.465
# Lesser    -106.0      37.95      42.75       44.5      24.75      45.48
# Greater    322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %% [markdown]
# # Variance and Standard Deviation

# %%
# Sample example to understand Mean Variance and Standard Deviation
import numpy as np

data = [4, 5, 6, 7, 8]
mean = np.mean(data)
variance = np.var(data)  # population variance
std_dev = np.std(data)   # population standard deviation

print("Mean:", mean)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 6.0
# Variance: 2.0
# Standard Deviation: 1.4142135623730951

# %%
from scipy.stats import skew, kurtosis

# Create an empty DataFrame with statistical rows
descriptive = pd.DataFrame(index=[
    "Count", "Mean", "Median", "Mode",
    "Min", "Max", "Range",
    "Q1:25%", "Q2:50%", "Q3:75%", "99%", "Q4:100%",
    "IQR", "1.5rule", "Lesser", "Greater",
    "Std", "Variance", "Skewness", "Kurtosis", "Sum"
])

# Loop over numerical columns
for columnName in quan:
    col = dataset[columnName].dropna()  # drop NaNs to avoid errors

    descriptive.at["Count", columnName] = col.count()
    descriptive.at["Mean", columnName] = col.mean()
    descriptive.at["Median", columnName] = col.median()
    descriptive.at["Mode", columnName] = col.mode().iloc[0] if not col.mode().empty else np.nan
    descriptive.at["Min", columnName] = col.min()
    descriptive.at["Max", columnName] = col.max()
    descriptive.at["Range", columnName] = col.max() - col.min()
    descriptive.at["Q1:25%", columnName] = col.quantile(0.25)
    descriptive.at["Q2:50%", columnName] = col.quantile(0.50)
    descriptive.at["Q3:75%", columnName] = col.quantile(0.75)
    descriptive.at["99%", columnName] = np.percentile(col, 99)
    descriptive.at["Q4:100%", columnName] = col.max()
    descriptive.at["IQR", columnName] = col.quantile(0.75) - col.quantile(0.25)
    descriptive.at["1.5rule", columnName] = 1.5 * descriptive.at["IQR", columnName]
    descriptive.at["Lesser", columnName] = descriptive.at["Q1:25%", columnName] - descriptive.at["1.5rule", columnName]
    descriptive.at["Greater", columnName] = descriptive.at["Q3:75%", columnName] + descriptive.at["1.5rule", columnName]
    descriptive.at["Std", columnName] = col.std()
    descriptive.at["Variance", columnName] = col.var()
    descriptive.at["Skewness", columnName] = skew(col)
    descriptive.at["Kurtosis", columnName] = kurtosis(col)
    descriptive.at["Sum", columnName] = col.sum()

# %%
 descriptive
# Out:
#                  sl_no         ssc_p         hsc_p      degree_p  \
# Count       215.000000    215.000000    215.000000    215.000000
# Mean        108.000000     67.303395     66.334744     66.370186
# Median      108.000000     67.000000     65.000000     66.000000
# Mode          1.000000     62.000000     63.000000     65.000000
# Min           1.000000     40.890000     42.750000     50.000000
# Max         215.000000     89.400000     91.150000     91.000000
# Range       214.000000     48.510000     48.400000     41.000000
# Q1:25%       54.500000     60.600000     60.900000     61.000000
# Q2:50%      108.000000     67.000000     65.000000     66.000000
# Q3:75%      161.500000     75.700000     73.000000     72.000000
# 99%         212.860000     87.000000     91.129000     83.860000
# Q4:100%     215.000000     89.400000     91.150000     91.000000
# IQR         107.000000     15.100000     12.100000     11.000000
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Skewness
descriptive.loc["Skewness"].astype(float).plot(kind='bar', ax=axes[0], color='orange')
axes[0].set_title("Skewness of Columns")
axes[0].set_ylabel("Skewness")

# Kurtosis
descriptive.loc["Kurtosis"].astype(float).plot(kind='bar', ax=axes[1], color='purple')
axes[1].set_title("Kurtosis of Columns")
axes[1].set_ylabel("Kurtosis")

for ax in axes:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.grid(axis='y')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert to numeric values (helpful in case of any tuples or objects)
descriptive_numeric = descriptive.apply(pd.to_numeric, errors='coerce')

plt.figure(figsize=(12, 10))
sns.heatmap(descriptive_numeric, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Descriptive Statistics Heatmap")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
